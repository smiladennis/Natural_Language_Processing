# %%
import pandas as pd

# %%
df = pd.read_csv("Chat with Dr Mahalakshmi.txt",header=None,on_bad_lines='skip',encoding='utf8')
df
# Out:
#            0                                                  1
# 0   15/01/20   11:13 am - Messages to this chat and calls ar...
# 1   15/01/20   11:13 am - Smila Subashini: Iniya pongal nalv...
# 2   15/01/20                  11:13 am - Smila Subashini: Smila
# 3   15/01/20             3:31 pm - Dr.Mahalakshmi: Ttan q Smila
# 4   15/01/20                  9:37 pm - Smila Subashini: Ok mam
# ..       ...                                                ...
# 69  02/03/20   8:48 pm - Smila Subashini: How s the climate ter
# 70  02/03/20                     8:53 pm - Dr.Mahalakshmi: ☀️☀️
# 71  02/03/20                       8:56 pm - Dr.Mahalakshmi: 👍🏽
# 72  03/03/20               12:23 pm - Dr.Mahalakshmi: Today 2pm
# 73  03/03/20   8:36 pm - Smila Subashini: Y do excess sleep ...
#
# [74 rows x 2 columns]

# %%
df.drop(0,axis=0,inplace=True) # delete 0 th row
df
# Out:
#            0                                                  1
# 1   15/01/20   11:13 am - Smila Subashini: Iniya pongal nalv...
# 2   15/01/20                  11:13 am - Smila Subashini: Smila
# 3   15/01/20             3:31 pm - Dr.Mahalakshmi: Ttan q Smila
# 4   15/01/20                  9:37 pm - Smila Subashini: Ok mam
# 5   31/01/20                 6:05 pm - Dr.Mahalakshmi: Tan q ma
# ..       ...                                                ...
# 69  02/03/20   8:48 pm - Smila Subashini: How s the climate ter
# 70  02/03/20                     8:53 pm - Dr.Mahalakshmi: ☀️☀️
# 71  02/03/20                       8:56 pm - Dr.Mahalakshmi: 👍🏽
# 72  03/03/20               12:23 pm - Dr.Mahalakshmi: Today 2pm
# 73  03/03/20   8:36 pm - Smila Subashini: Y do excess sleep ...
#
# [73 rows x 2 columns]

# %%
df.columns='Date','Chat'
df
# Out:
#         Date                                               Chat
# 1   15/01/20   11:13 am - Smila Subashini: Iniya pongal nalv...
# 2   15/01/20                  11:13 am - Smila Subashini: Smila
# 3   15/01/20             3:31 pm - Dr.Mahalakshmi: Ttan q Smila
# 4   15/01/20                  9:37 pm - Smila Subashini: Ok mam
# 5   31/01/20                 6:05 pm - Dr.Mahalakshmi: Tan q ma
# ..       ...                                                ...
# 69  02/03/20   8:48 pm - Smila Subashini: How s the climate ter
# 70  02/03/20                     8:53 pm - Dr.Mahalakshmi: ☀️☀️
# 71  02/03/20                       8:56 pm - Dr.Mahalakshmi: 👍🏽
# 72  03/03/20               12:23 pm - Dr.Mahalakshmi: Today 2pm
# 73  03/03/20   8:36 pm - Smila Subashini: Y do excess sleep ...
#
# [73 rows x 2 columns]

# %%
message=df['Chat'].str.split('-',n=1,expand=True)
df['Time']=message[0]

# %%
df
# Out:
#         Date                                               Chat        Time
# 1   15/01/20   11:13 am - Smila Subashini: Iniya pongal nalv...   11:13 am
# 2   15/01/20                  11:13 am - Smila Subashini: Smila   11:13 am
# 3   15/01/20             3:31 pm - Dr.Mahalakshmi: Ttan q Smila    3:31 pm
# 4   15/01/20                  9:37 pm - Smila Subashini: Ok mam    9:37 pm
# 5   31/01/20                 6:05 pm - Dr.Mahalakshmi: Tan q ma    6:05 pm
# ..       ...                                                ...         ...
# 69  02/03/20   8:48 pm - Smila Subashini: How s the climate ter    8:48 pm
# 70  02/03/20                     8:53 pm - Dr.Mahalakshmi: ☀️☀️    8:53 pm
# 71  02/03/20                       8:56 pm - Dr.Mahalakshmi: 👍🏽    8:56 pm
# 72  03/03/20               12:23 pm - Dr.Mahalakshmi: Today 2pm   12:23 pm
# 73  03/03/20   8:36 pm - Smila Subashini: Y do excess sleep ...    8:36 pm
#
# [73 rows x 3 columns]

# %%
message1=message[1].str.split(':',n=1,expand=True)
message1
# Out:
#                    0                               1
# 1    Smila Subashini   Iniya pongal nalvalthukal🌞🌴🏄🎇
# 2    Smila Subashini                           Smila
# 3     Dr.Mahalakshmi                    Ttan q Smila
# 4    Smila Subashini                          Ok mam
# 5     Dr.Mahalakshmi                        Tan q ma
# ..               ...                             ...
# 69   Smila Subashini           How s the climate ter
# 70    Dr.Mahalakshmi                            ☀️☀️
# 71    Dr.Mahalakshmi                              👍🏽
# 72    Dr.Mahalakshmi                       Today 2pm
# 73   Smila Subashini    Y do excess sleep is ter mam
#
# [73 rows x 2 columns]

# %%
df['Name']=message1[0]
df['Chat']=message1[1]

# %%
df=df[['Date','Time','Name','Chat']]
df
# Out:
#         Date        Time              Name                            Chat
# 1   15/01/20   11:13 am    Smila Subashini   Iniya pongal nalvalthukal🌞🌴🏄🎇
# 2   15/01/20   11:13 am    Smila Subashini                           Smila
# 3   15/01/20    3:31 pm     Dr.Mahalakshmi                    Ttan q Smila
# 4   15/01/20    9:37 pm    Smila Subashini                          Ok mam
# 5   31/01/20    6:05 pm     Dr.Mahalakshmi                        Tan q ma
# ..       ...         ...               ...                             ...
# 69  02/03/20    8:48 pm    Smila Subashini           How s the climate ter
# 70  02/03/20    8:53 pm     Dr.Mahalakshmi                            ☀️☀️
# 71  02/03/20    8:56 pm     Dr.Mahalakshmi                              👍🏽
# 72  03/03/20   12:23 pm     Dr.Mahalakshmi                       Today 2pm
# 73  03/03/20    8:36 pm    Smila Subashini    Y do excess sleep is ter mam
#
# [73 rows x 4 columns]

# %%
'''df=df.drop(0)
df.columns=['Date','Chat']
Message=df["Chat"].str.split("-",n=1,expand=True)
df["Time"]=Message[0]
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df=df[["Date","Time","Name","Chat"]]
df'''
# Out:
# 'df=df.drop(0)\ndf.columns=[\'Date\',\'Chat\']\nMessage=df["Chat"].str.split("-",n=1,expand=True)\ndf["Time"]=Message[0]\nMessage1=Message[1].str.split(":",n=1,expand=True)\ndf["Name"]=Message1[0]\ndf["Chat"]=Message1[1]\ndf=df[["Date","Time","Name","Chat"]]\ndf'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 1 to 73
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    73 non-null     object
#  1   Time    73 non-null     object
#  2   Name    73 non-null     object
#  3   Chat    73 non-null     object
# dtypes: object(4)
# memory usage: 2.4+ KB

# %%
#import nltk
# 1. Download the required VADER lexicon (Run this once)
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#         Date        Time              Name                            Chat
# 1   15/01/20   11:13 am    Smila Subashini   Iniya pongal nalvalthukal🌞🌴🏄🎇
# 2   15/01/20   11:13 am    Smila Subashini                           Smila
# 3   15/01/20    3:31 pm     Dr.Mahalakshmi                    Ttan q Smila
# 4   15/01/20    9:37 pm    Smila Subashini                          Ok mam
# 5   31/01/20    6:05 pm     Dr.Mahalakshmi                        Tan q ma
# ..       ...         ...               ...                             ...
# 69  02/03/20    8:48 pm    Smila Subashini           How s the climate ter
# 70  02/03/20    8:53 pm     Dr.Mahalakshmi                            ☀️☀️
# 71  02/03/20    8:56 pm     Dr.Mahalakshmi                              👍🏽
# 72  03/03/20   12:23 pm     Dr.Mahalakshmi                       Today 2pm
# 73  03/03/20    8:36 pm    Smila Subashini    Y do excess sleep is ter mam
#
# [73 rows x 4 columns]

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.296}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#         Date        Time              Name                            Chat  \
# 1   15/01/20   11:13 am    Smila Subashini   Iniya pongal nalvalthukal🌞🌴🏄🎇
# 2   15/01/20   11:13 am    Smila Subashini                           Smila
# 3   15/01/20    3:31 pm     Dr.Mahalakshmi                    Ttan q Smila
# 4   15/01/20    9:37 pm    Smila Subashini                          Ok mam
# 5   31/01/20    6:05 pm     Dr.Mahalakshmi                        Tan q ma
# ..       ...         ...               ...                             ...
# 69  02/03/20    8:48 pm    Smila Subashini           How s the climate ter
# 70  02/03/20    8:53 pm     Dr.Mahalakshmi                            ☀️☀️
# 71  02/03/20    8:56 pm     Dr.Mahalakshmi                              👍🏽
# 72  03/03/20   12:23 pm     Dr.Mahalakshmi                       Today 2pm
# 73  03/03/20    8:36 pm    Smila Subashini    Y do excess sleep is ter mam
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 4   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...     0.296      0.0
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# ..                                                ...       ...      ...
# 69  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 71  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
#
#     Postive  Neutral comp_score
# 1     0.000    1.000        pos
# 2     0.000    1.000        pos
# 3     0.000    1.000        pos
# 4     0.688    0.312        pos
# 5     0.000    1.000        pos
# ..      ...      ...        ...
# 69    0.000    1.000        pos
# 70    0.000    1.000        pos
# 71    0.000    1.000        pos
# 72    0.000    1.000        pos
# 73    0.000    1.000        pos
#
# [73 rows x 10 columns]

# %%
pos
# Out:
#             count
# comp_score
# pos            69
# neg             4

# %%
dataset['Negtive'].value_counts()
# Out:
# Negtive
# 0.000    69
# 0.688     1
# 0.306     1
# 0.535     1
# 0.773     1
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
#Topic_Modelling_By_Decomposition(NMF)
from sklearn.decomposition import LatentDirichletAllocation  
lda_model=LatentDirichletAllocation(n_components=5,random_state=42)
lda_model.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
lda_model.n_features_in_
dir(lda_model)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_approx_bound',
#  '_build_request_for_signature',
#  '_check_non_neg_array',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_e_step',
#  '_em_step',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_html_repr',
#  '_init_latent_vars',
#  '_n_features_out',
#  '_parameter_constraints',
#  '_perplexity_precomp_distr',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_sklearn_auto_wrap_output_keys',
#  '_unnormalized_transform',
#  '_validate_params',
#  'batch_size',
#  'bound_',
#  'components_',
#  'doc_topic_prior',
#  'doc_topic_prior_',
#  'evaluate_every',
#  'exp_dirichlet_component_',
#  'fit',
#  'fit_transform',
#  'get_feature_names_out',
#  'get_metadata_routing',
#  'get_params',
#  'learning_decay',
#  'learning_method',
#  'learning_offset',
#  'max_doc_update_iter',
#  'max_iter',
#  'mean_change_tol',
#  'n_batch_iter_',
#  'n_components',
#  'n_features_in_',
#  'n_iter_',
#  'n_jobs',
#  'partial_fit',
#  'perp_tol',
#  'perplexity',
#  'random_state',
#  'random_state_',
#  'score',
#  'set_output',
#  'set_params',
#  'set_transform_request',
#  'topic_word_prior',
#  'topic_word_prior_',
#  'total_samples',
#  'transform',
#  'verbose']

# %%
for index,topic in enumerate(lda_model.components_):
    results=([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['today', 'smila', 'gn', 'mam', 'ter', 'photo', 'fine', 'fne', 'dance', 'ma']
# ['fne', 'fine', 'today', 'photo', 'attached', 'file', 'wat', 'ter', 'smila', 'mam']
# ['smila', 'fine', 'ma', 'today', 'means', 'happy', 'ah', 'ok', 'mam', 'gn']

# %%
topic_results=lda_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)

# %%
df
# Out:
#         Date        Time              Name                            Chat  \
# 0   15/01/20   11:13 am    Smila Subashini   Iniya pongal nalvalthukal🌞🌴🏄🎇
# 1   15/01/20   11:13 am    Smila Subashini                           Smila
# 2   15/01/20    3:31 pm     Dr.Mahalakshmi                    Ttan q Smila
# 3   15/01/20    9:37 pm    Smila Subashini                          Ok mam
# 4   31/01/20    6:05 pm     Dr.Mahalakshmi                        Tan q ma
# ..       ...         ...               ...                             ...
# 68  02/03/20    8:48 pm    Smila Subashini           How s the climate ter
# 69  02/03/20    8:53 pm     Dr.Mahalakshmi                            ☀️☀️
# 70  02/03/20    8:56 pm     Dr.Mahalakshmi                              👍🏽
# 71  03/03/20   12:23 pm     Dr.Mahalakshmi                       Today 2pm
# 72  03/03/20    8:36 pm    Smila Subashini    Y do excess sleep is ter mam
#
#                                                scores  compound  Negtive  \
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 3   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...     0.296      0.0
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# ..                                                ...       ...      ...
# 68  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 69  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 71  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...     0.000      0.0
#
#     Postive  Neutral comp_score  Topic
# 0     0.000    1.000        pos      0
# 1     0.000    1.000        pos      1
# 2     0.000    1.000        pos      1
# 3     0.688    0.312        pos      2
# 4     0.000    1.000        pos      0
# ..      ...      ...        ...    ...
# 68    0.000    1.000        pos      1
# 69    0.000    1.000        pos      0
# 70    0.000    1.000        pos      0
# 71    0.000    1.000        pos      2
# 72    0.000    1.000        pos      1
#
# [73 rows x 11 columns]

# %%
df["Topic"].value_counts()
# Out:
# Topic
# 0    38
# 1    21
# 2    14
# Name: count, dtype: int64

# %%
#!pip install wordCloud

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud_1.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
# Out:
# Successfully created
